# %% [markdown]
# Multi-Shot Prompting

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_BASE = os.getenv("OPENAI_API_BASE")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
MODEL = os.getenv("MODEL")

prompt_system = """Predict up to 5 emojis as a response to a text chat message. The output should only include emojis.

input: The new visual design is blowing my mind 🤯
output: ➕,💘, ❤🔥

input: Well that looks great regardless
output: ❤️,🪄

input: Unfortunately this won't work
output: 💔,😔

input: sounds good, I'll look into that
output: 🙏,👍

input: 10hr cut of jeff goldblum laughing URL
output: 😂,💀,⚰️"""

userinput = """great , this is party time"""


client = OpenAI(base_url=OPENAI_API_BASE, api_key=OPENAI_API_KEY)

response = client.chat.completions.create(model=MODEL, 
                                        messages=[
                                            {"role": "system", "content": prompt_system}, 
                                            {"role": "user", "content": userinput}])

print(response.choices[0].message.content)
# Out:
# 🎉, 🕺, 🎊, 🔥, 💃

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_BASE = os.getenv("OPENAI_API_BASE")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
MODEL = os.getenv("MODEL")

prompt_system = """you are datasource decider ,who is responsible for deciding the data sources for a user query , 
and you are response should be  database or Buisness knowledge base or General knowledge base

input: what is meant by graph?
output: General knowledge base

input: what is the profit of the company in 2021?
output: database

input: what is the prcocess to release the document?
output: Buisness knowledge base

input: what is the structure of the company?
output: Buisness knowledge base

input: what is the gross revenue of the company?
output: database

input: what is the workday url of the company?
output: Buisness knowledge base

input: what is the gross revenue of the company?
output: database

input: what is the temperature in newyork?
output: General knowledge base

input: what is the time ?
output: General knowledge base

"""

userinput = "what is node in buisness?"


client = OpenAI(base_url=OPENAI_API_BASE, api_key=OPENAI_API_KEY)

response = client.chat.completions.create(model=MODEL, 
                                        messages=[
                                            {"role": "system", "content": prompt_system}, 
                                            {"role": "user", "content": userinput}])

print(response.choices[0].message.content)
# Out:
# Business knowledge base.
#
# A node in business can refer to various concepts depending on the context, but commonly it is used to describe a key component or element within an organizational structure or system.
#
# In this sense, it might represent:
#
# - A person or employee within the company
# - A team or department
# - A project or initiative
# - A location or office
# - An asset or resource
#
# However, more specifically in the context of business process and network analysis (BPMN), a node often represents an event, activity, or decision point in a business process flow.

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_BASE = os.getenv("OPENAI_API_BASE")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
MODEL = os.getenv("MODEL")

prompt_system = """you are datasource decider ,who is responsible for deciding the data sources for a user query , 
and you are response should be  database or Buisness knowledge base or General knowledge base

input: what is meant by graph?
output: since the question is genric , General knowledge base

input: what is the profit of the company in 2021?
output: since the question is data related to the company , database

input: what is the prcocess to release the document?
output: since the question is related to the company,  Buisness knowledge base

input: what is the structure of the company?
output: since the question is related to the company, Buisness knowledge base

input: what is the gross revenue of the company?
output: since the question is related data related to the company, database

input: what is the workday url of the company?
output: since the question is related to the company, Buisness knowledge base

input: what is the gross revenue of the company?
output: since the question is related data related to the company, database

input: what is the temperature in newyork?
output: since the question is genric ,General knowledge base

input: what is the time ?
output: since the question is genric ,General knowledge base

input: what is node in buisness ?
output: since the question is non identifible it may be either General knowledge or Buisness knowledge , Recommend is General knowledge base

"""

userinput = "what is node in buisness?"


client = OpenAI(base_url=OPENAI_API_BASE, api_key=OPENAI_API_KEY)

response = client.chat.completions.create(model=MODEL, 
                                        messages=[
                                            {"role": "system", "content": prompt_system}, 
                                            {"role": "user", "content": userinput}])

print(response.choices[0].message.content)
# Out:
# since the question is non identifible it may be either General knowledge or Buisness knowledge.
#
# Recommend: Business Knowledge Base
